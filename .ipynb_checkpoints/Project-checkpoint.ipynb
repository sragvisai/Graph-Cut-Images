# %%
from skimage import io, util
s = "https://raw.githubusercontent.com/axu2/image-quilting/master/"

texture = io.imread(s + "test.png")
io.imshow(texture)
io.show()
image = util.img_as_float(texture)

# %%
from PIL import Image
from numpy import asarray
import numpy as np
img = Image.open('C:/Users/nsrag/OneDrive/Desktop/UMBC/SEM2/DAA/Projects/s.png')
numpydata = asarray(img)
#print(numpydata)
numpydata = np.delete(numpydata,3,1)
print("Here")
print(numpydata)
# Out:
# [[[255 255 255   0]
#   [255 255 255   0]
#   [255 255 255   0]
#   ...
#   [255 255 255   0]
#   [255 255 255   0]
#   [255 255 255   0]]
#
#  [[255 255 255   0]
#   [255 255 255   0]
#   [255 255 255   0]
#   ...
#   [255 255 255   0]
#   [255 255 255   0]
#   [255 255 255   0]]
#
#  [[255 255 255   0]
#   [255 255 255   0]
#   [255 255 255   0]
#   ...
#   [255 255 255   0]
#   [255 255 255   0]
#   [255 255 255   0]]
#
#  ...
#
#  [[255 255 255   0]
#   [255 255 255   0]
#   [255 255 255   0]
#   ...
#   [255 255 255   0]
#   [255 255 255   0]
#   [255 255 255   0]]
#
#  [[255 255 255   0]
#   [255 255 255   0]
#   [255 255 255   0]
#   ...
#   [255 255 255   0]
#   [255 255 255   0]
#   [255 255 255   0]]
#
#  [[255 255 255   0]
#   [255 255 255   0]
#   [255 255 255   0]
#   ...
#   [255 255 255   0]
#   [255 255 255   0]
#   [255 255 255   0]]]
# Here
# [[[255 255 255   0]
#   [255 255 255   0]
#   [255 255 255   0]
#   ...
#   [255 255 255   0]
#   [255 255 255   0]
# ...
