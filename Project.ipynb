# %%
from skimage import io, util
s = "https://raw.githubusercontent.com/axu2/image-quilting/master/"

texture = io.imread(s + "test.png")
io.imshow(texture)
io.show()
image = util.img_as_float(texture)
image = np.delete(image,3,2)

# %%
print(image.shape)
print(image)
# Out:
# (64, 64, 3)
# [[[0.0627451  0.04705882 0.05490196]
#   [0.03137255 0.03529412 0.02352941]
#   [0.10588235 0.10588235 0.07843137]
#   ...
#   [0.20784314 0.2        0.11764706]
#   [0.13333333 0.10196078 0.09019608]
#   [0.03137255 0.03529412 0.02352941]]
#
#  [[0.16862745 0.21960784 0.16078431]
#   [0.07843137 0.10588235 0.0745098 ]
#   [0.07843137 0.10980392 0.05098039]
#   ...
#   [0.25882353 0.22352941 0.19215686]
#   [0.10196078 0.07843137 0.08627451]
#   [0.10196078 0.07843137 0.08627451]]
#
#  [[0.1254902  0.21176471 0.20392157]
#   [0.23137255 0.34117647 0.27843137]
#   [0.23137255 0.34117647 0.27843137]
#   ...
#   [0.17647059 0.2        0.1372549 ]
#   [0.05882353 0.10588235 0.0745098 ]
#   [0.10588235 0.15686275 0.14509804]]
#
#  ...
#
#  [[0.08235294 0.10980392 0.10588235]
#   [0.04705882 0.09019608 0.09019608]
#   [0.15686275 0.15686275 0.14509804]
#   ...
#   [0.1254902  0.21176471 0.20392157]
#   [0.17254902 0.22745098 0.20784314]
# ...

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('todo.jpeg')
print(image_rgb.shape)
plt.imshow(image_rgb)
print(image_rgb)
# Out:
# (64, 64, 3)
# [[[12 13  7]
#   [ 9 12  3]
#   [23 29 17]
#   ...
#   [52 49 32]
#   [30 27 20]
#   [10  6  5]]
#
#  [[43 53 45]
#   [16 28 18]
#   [18 32 17]
#   ...
#   [58 59 41]
#   [30 31 23]
#   [20 20 18]]
#
#  [[29 57 45]
#   [58 86 72]
#   [59 90 72]
#   ...
#   [44 51 33]
#   [14 21 13]
#   [30 39 34]]
#
#  ...
#
#  [[18 29 25]
#   [17 26 21]
#   [37 42 36]
#   ...
#   [33 55 43]
#   [38 58 49]
#   [27 44 36]]
#
#  [[ 3  8  4]
#   [13 18 12]
#   [48 51 42]
#   ...
#   [10 23 14]
#   [ 6 22 11]
#   [11 29 17]]
#
#  [[13 15 10]
#   [23 26 19]
#   [38 41 32]
#   ...
#   [28 38 30]
#   [ 9 22 12]
#   [ 9 27 13]]]

# %%
print(img[:,-2 : 64])
# Out:
# [[[ 20  27  30]
#   [  5   6  10]]
#
#  [[ 23  31  30]
#   [ 18  20  20]]
#
#  [[ 13  21  14]
#   [ 34  39  30]]
#
#  [[ 18  29  13]
#   [ 65  76  56]]
#
#  [[ 34  51  24]
#   [ 95 111  80]]
#
#  [[ 55  76  43]
#   [120 141 102]]
#
#  [[ 89 116  76]
#   [149 178 132]]
#
#  [[108 141  96]
#   [157 194 144]]
#
#  [[127 164 118]
#   [185 229 176]]
#
#  [[132 174 126]
#   [185 234 178]]
#
#  [[134 180 128]
#   [179 230 172]]
#
#  [[141 187 134]
#   [179 231 171]]
#
#  [[147 192 135]
#   [182 234 170]]
#
#  [[145 189 130]
#   [185 234 166]]
#
#  [[141 184 121]
#   [186 234 162]]
#
#  [[133 175 110]
#   [182 229 153]]
#
#  [[112 154  89]
#   [183 233 155]]
#
#  [[ 97 132  75]
#   [130 176 103]]
#
#  [[ 87 116  67]
#   [112 148  88]]
#
#  [[ 52  72  37]
#   [ 98 121  77]]
#
#  [[ 27  38  18]
#   [ 73  84  58]]
#
#  [[ 23  26  17]
#   [ 40  42  30]]
#
#  [[ 22  22  22]
#   [ 21  17  16]]
#
#  [[ 49  53  54]
#   [ 53  50  52]]
#
#  [[ 82  96  94]
#   [ 64  72  71]]
#
#  [[ 97 123 117]
# ...

# %%
print(img[0][62])
print(img[0][63])
# Out:
# [20 27 30]
# [ 5  6 10]

# %%
def getAvg(pixelArray):
    return (sum(pixelArray)/3)

# %%
#trying this with cv2
#offset is hardcoded to 2

#left side be the actual image and right be the new patch

#left side required matrix
left = []
right = []

left = img[:,-2:281]
right = img[:,0:2]

print("Left",left.shape)
print("Right",right.shape)
# Out:
# Left (64, 2, 3)
# Right (64, 2, 3)

# %%
def getEdgeCost(leftPixel,rightPixel):
    return abs(leftpixel[0] - rightPixel[0]) + abs(leftPixel[1] - rightPixel[1])

# %%
#initiate the adjacency matrix (64 x 64)

#a row of 64 0's
rows = []
for i in range(64):
    rows.append(0)

#the adj matrix
matrix = []
for i in range(0,64):
    matrix.append(rows)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14552/3225285614.py in <module>
# ----> 1 print(matrix.shape())
#
# AttributeError: 'list' object has no attribute 'shape'
